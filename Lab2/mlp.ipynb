# %% [markdown]
# _In this notebook, every question will be marked by a blue border, and answers should be provided in cells in a green border. All code-related answers are preceded by a #TODO._

# %% [markdown]
# ## Students (to fill in)
#
#  - BONNET Ronan (4IR-A1)
#  - CAZENEUVE Anna (4IR-A1)

# %% [markdown]
# # Introduction
#
# The objective of this lab is to dive into particular kind of neural network: the *Multi-Layer Perceptron* (MLP).
#
# To start, let us take the dataset from the previous lab (hydrodynamics of sailing boats) and use scikit-learn to train a MLP instead of our hand-made single perceptron.
# The code below is already complete and is meant to give you an idea of how to construct an MLP with scikit-learn. You can execute it, taking the time to understand the idea behind each cell.

# %%
# Importing the dataset
import numpy as np
dataset = np.genfromtxt("yacht_hydrodynamics.data", delimiter='')
X = dataset[:, :-1]
Y = dataset[:, -1]

# %%
# Preprocessing: scale input data 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
# Split dataset into training and test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y,random_state=1, test_size = 0.20)

# %%
# Define a multi-layer perceptron (MLP) network for regression
from sklearn.neural_network import MLPRegressor
mlp = MLPRegressor(max_iter=3000, random_state=1) # define the model, with default params
mlp.fit(x_train, y_train) # train the MLP
# Out:
# MLPRegressor(max_iter=3000, random_state=1)

# %%
# Evaluate the model
from matplotlib import pyplot as plt

print('Train score: ', mlp.score(x_train, y_train))
print('Test score:  ', mlp.score(x_test, y_test))
plt.plot(mlp.loss_curve_)
plt.xlabel("Iterations")
plt.ylabel("Loss")
# Out:
# Train score:  0.9940765369322633
# Test score:   0.9899773031580283
# Text(0, 0.5, 'Loss')

# %%
# Plot the results
num_samples_to_plot = 20
plt.plot(y_test[0:num_samples_to_plot], 'ro', label='y')
yw = mlp.predict(x_test)
plt.plot(yw[0:num_samples_to_plot], 'bx', label='$\hat{y}$')
plt.legend()
plt.xlabel("Examples")
plt.ylabel("f(examples)")
# Out:
# Text(0, 0.5, 'f(examples)')

# %% [markdown]
# ### Analyzing the network
#
# Many details of the network are currently hidden as default parameters.
#
# Using the [documentation of the MLPRegressor](https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPRegressor.html), answer the following questions.
# <!-- Question Start -->
# <div style="border: 1px solid blue; padding: 20px;border-radius: 5px;">
#
# - What is the structure of the network?
# - What it is the algorithm used for training? Is there algorithm available that we mentioned during the courses?
# - How does the training algorithm decides to stop the training?
# </div>
# <!-- Question End -->

# %% [markdown]
# <!-- Answer Section Start -->
# <div style="border: 1px solid green; padding: 10px; margin-top: 10px; border-radius: 5px">
#
# **Your answer here:**
#
# - MLP, 100 hiddens layers, with ReLU activation function.
# - By default it is 'adam' algorithm. Yes, there's stochastic gradient descent.
# - Early start is disabled by default. It stops on max_iter.
#
#
#
#
#
# </div>
# <!-- Answer Section End -->

# %% [markdown]
# # Onto a more challenging dataset: house prices
#
# For the rest of this lab, we will use the (more challenging) [California Housing Prices dataset](https://www.kaggle.com/datasets/camnugent/california-housing-prices).

# %%
# clean all previously defined variables for the sailing boats
# %reset -f

# %%
"""Import the required modules"""
from sklearn.datasets import fetch_california_housing
from sklearn.utils import shuffle
import pandas as pd

cal_housing = fetch_california_housing()
print(f"dataset type : {type(cal_housing)}")
print(f"number of data : {len(cal_housing.data)}")
X_all = pd.DataFrame(cal_housing.data,columns=cal_housing.feature_names)
y_all = pd.DataFrame(cal_housing.target,columns=["target"])

X_all, y_all = shuffle(X_all, y_all, random_state=1)

display(X_all.head(10)) # print the first 10 values
display(y_all.head(10))
# Out:
# dataset type : <class 'sklearn.utils._bunch.Bunch'>
# number of data : 20640
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 4712   3.2500      39.0  4.503205   1.073718      1109.0  1.777244     34.06
# 2151   1.9784      37.0  4.988584   1.038813      1143.0  2.609589     36.78
# 15927  4.0132      46.0  4.480296   1.012315      1534.0  3.778325     37.73
# 82     1.5208      52.0  3.908046   1.114943       200.0  2.298851     37.81
# 8161   5.1795      37.0  5.406360   1.024735       711.0  2.512367     33.82
# 6636   7.3715      17.0  5.006098   0.993902       229.0  1.396341     34.15
# 17333  5.2990      12.0  7.214932   1.047511      1200.0  2.714932     34.91
# 19081  2.3276      29.0  4.731076   1.115538      1124.0  2.239044     38.31
# 13298  3.4950      35.0  4.956522   0.952569       729.0  2.881423     34.08
# 7157   3.1895      45.0  5.533333   1.166667       302.0  5.033333     34.04
#
#        Longitude
# 4712     -118.36
# 2151     -119.78
# 15927    -122.42
# 82       -122.28
# 8161     -118.13
# 6636     -118.16
# 17333    -120.44
# 19081    -122.48
# 13298    -117.64
# 7157     -118.16
#        target
# 4712    3.550
# 2151    0.707
# 15927   2.294
# 82      1.125
# 8161    2.254
# 6636    2.630
# 17333   2.268
# 19081   1.662
# 13298   1.180
# 7157    1.563

# %% [markdown]
# Note that each row of the dataset represents a **group of houses** (one district). The `target` variable denotes the average house value in units of 100.000 USD. Median Income is per 10.000 USD.

# %% [markdown]
# ### Data Preparation
#
# The dataset consists of 20,000 datas. We first extract the last 5,000 for test samples, which we will use later.
#
# For training and validation, we will use a subset consisting of only 2,000 datas to speed up computations.
#
# <!-- Question Start -->
# <div style="border: 1px solid blue; padding: 20px;border-radius: 5px;">
#
# - Split those 2000 remaining dataset between a training set and a validation set (see usage of `train_test_split` function earlier)
# - Why did you choose this partition?
# - What is the purpose of each subset (train, validation, test) ?
#
# </div>
# <!-- Question End -->
#
#
# Please use the conventional names `X_train`, `X_val`, `y_train` and `y_val`.

# %%
# use the last N samples for test (for later use)
num_test_samples = 5000
X_test, y_test = X_all[-num_test_samples:], y_all[-num_test_samples:]

# only use the first N samples to limit training time
num_samples = 2000
X, y = X_all[:num_samples], y_all[:num_samples]

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y,random_state=1, test_size = 0.20)

# %% [markdown]
# <!-- Answer Section Start -->
# <div style="border: 1px solid green; padding: 10px; margin-top: 10px; border-radius: 5px">
#
# **Your answer here:**
#
# - We chose 20%, because empirically it is the best partition.
#
# - Purpose of each subset:
#     - Train: Train the model on this data.
#     - Validation: While training, we use this set to ensure that the model does not overfit. (biased)
#     - Test: After training, it is used to give the accuracy of the model.
#
#
#
#
#
# </div>
# <!-- Answer Section End -->

# %% [markdown]
# ### Scaling the input data
#
#
# A step of **scaling** of the data is often useful to ensure that all input data centered on 0 and with a fixed variance.
#
# Standardization of a dataset is a common requirement for many machine learning estimators: they might behave badly if the individual features do not more or less look like standard normally distributed data (e.g. Gaussian with 0 mean and unit variance). The function `StandardScaler` from `sklearn.preprocessing` computes the standard score of a sample as:
#
# ```
# z = (x - u) / s
# ```
#
# where `u` is the mean of the training samples, and `s` is the standard deviation of the training samples.
#
# <!-- Question Start -->
# <div style="border: 1px solid blue; padding: 20px;border-radius: 5px;">
#
# - Using the `StandardScaler`, first fit this scaler on your training dataset (`X_train`), then use this fitted scaler to transform the training dataset, the validation dataset (`X_val`), and the test dataset (`X_test`).
#
#
# - Why is it important to fit the scaler only on the training data and not on the entire dataset or separately on each dataset?
#
# </div>
# <!-- Question End -->
#
# [Documentation of standard scaler in scikit learn](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

# %% [markdown]
# <!-- Answer Section Start -->
# <div style="border: 1px solid green; padding: 10px; margin-top: 10px; border-radius: 5px">
#
# **Your answer here:**
#
# If we fit on data that is different from the training data, then we might not have a good scale on training data.
# We do not want to get information from test and validation data sets.
#
#
#
# </div>
# <!-- Answer Section End -->

# %% [markdown]
# ## Overfitting
#
# In this part, we are only interested in maximizing the **train score**, i.e., having the network memorize the training examples as well as possible. While doing this, you should (1) remain within two minutes of training time, and (2) obtain a score that is greater than 0.90.
#
# <!-- Question Start -->
# <div style="border: 1px solid blue; padding: 20px;border-radius: 5px;">
#
# - Propose a parameterization of the network (number of neurons per layer, number of layers, epochs, learning rates) that will maximize the train score (without considering the test score). Ensure that you disable any form of internal validation checks such as early stopping to promote overfitting.
#
# - Is the **validation** score substantially smaller than the **train** score (indicator of overfitting) ?
# - Explain how the parameters you chose allow the learned model to overfit.
# </div>
# <!-- Question End -->

# %%
from sklearn.neural_network import MLPRegressor
regr = MLPRegressor(random_state=1, max_iter=800, n_iter_no_change=1000, verbose=True, hidden_layer_sizes=(100,100), activation='relu', learning_rate_init=8e-3, solver='adam')

regr.fit(X_train, y_train)
train_score = regr.score(X_train, y_train)
print("Training Score:", train_score)
val_score = regr.score(X_val,y_val)
print("Validation Score:", val_score)
# Out:
# /home/ronan/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 1, loss = 1.31938729
# Iteration 2, loss = 0.38545673
# Iteration 3, loss = 0.32432126
# Iteration 4, loss = 0.24808604
# Iteration 5, loss = 0.22011680
# Iteration 6, loss = 0.19952754
# Iteration 7, loss = 0.19184359
# Iteration 8, loss = 0.18458739
# Iteration 9, loss = 0.17684875
# Iteration 10, loss = 0.17219054
# Iteration 11, loss = 0.16902665
# Iteration 12, loss = 0.16566648
# Iteration 13, loss = 0.16207517
# Iteration 14, loss = 0.16650454
# Iteration 15, loss = 0.15450425
# Iteration 16, loss = 0.15261713
# Iteration 17, loss = 0.15231718
# Iteration 18, loss = 0.15018155
# Iteration 19, loss = 0.14939672
# Iteration 20, loss = 0.14624139
# Iteration 21, loss = 0.14035654
# Iteration 22, loss = 0.14069284
# Iteration 23, loss = 0.14452186
# Iteration 24, loss = 0.14395877
# Iteration 25, loss = 0.14636230
# Iteration 26, loss = 0.14958269
# Iteration 27, loss = 0.14921366
# Iteration 28, loss = 0.14678654
# Iteration 29, loss = 0.14229892
# Iteration 30, loss = 0.13771867
# Iteration 31, loss = 0.13032280
# Iteration 32, loss = 0.13434276
# Iteration 33, loss = 0.12983661
# Iteration 34, loss = 0.12505998
# Iteration 35, loss = 0.12613277
# Iteration 36, loss = 0.12986626
# Iteration 37, loss = 0.12315939
# Iteration 38, loss = 0.12194490
# Iteration 39, loss = 0.11832152
# Iteration 40, loss = 0.11740145
# Iteration 41, loss = 0.11721276
# Iteration 42, loss = 0.11299254
# Iteration 43, loss = 0.11199259
# Iteration 44, loss = 0.11493916
# Iteration 45, loss = 0.11217783
# Iteration 46, loss = 0.10988046
# Iteration 47, loss = 0.11190240
# Iteration 48, loss = 0.12046164
# Iteration 49, loss = 0.11549572
# Iteration 50, loss = 0.11348855
# Iteration 51, loss = 0.11240791
# Iteration 52, loss = 0.10838767
# Iteration 53, loss = 0.10906940
# Iteration 54, loss = 0.11709020
# Iteration 55, loss = 0.10578172
# Iteration 56, loss = 0.12363502
# Iteration 57, loss = 0.12138279
# Iteration 58, loss = 0.10693678
# Iteration 59, loss = 0.10300735
# Iteration 60, loss = 0.10349692
# Iteration 61, loss = 0.09872394
# Iteration 62, loss = 0.09241260
# Iteration 63, loss = 0.09295307
# Iteration 64, loss = 0.09257545
# Iteration 65, loss = 0.09373569
# Iteration 66, loss = 0.09769181
# Iteration 67, loss = 0.09190400
# Iteration 68, loss = 0.09468606
# Iteration 69, loss = 0.09123149
# Iteration 70, loss = 0.09273595
# Iteration 71, loss = 0.08897034
# Iteration 72, loss = 0.08108972
# Iteration 73, loss = 0.08567733
# Iteration 74, loss = 0.08028921
# Iteration 75, loss = 0.07949276
# Iteration 76, loss = 0.07635108
# Iteration 77, loss = 0.07540300
# Iteration 78, loss = 0.07839230
# Iteration 79, loss = 0.07692255
# Iteration 80, loss = 0.08361761
# Iteration 81, loss = 0.09136505
# Iteration 82, loss = 0.08951534
# Iteration 83, loss = 0.09095312
# Iteration 84, loss = 0.08300458
# Iteration 85, loss = 0.08095669
# Iteration 86, loss = 0.08558220
# Iteration 87, loss = 0.08263126
# Iteration 88, loss = 0.07755724
# Iteration 89, loss = 0.08221309
# Iteration 90, loss = 0.07500175
# Iteration 91, loss = 0.07054092
# Iteration 92, loss = 0.07176926
# Iteration 93, loss = 0.07425555
# Iteration 94, loss = 0.07629003
# Iteration 95, loss = 0.07567995
# Iteration 96, loss = 0.07701351
# Iteration 97, loss = 0.07159322
# Iteration 98, loss = 0.06863944
# Iteration 99, loss = 0.06803237
# Iteration 100, loss = 0.07188023
# Iteration 101, loss = 0.07485014
# Iteration 102, loss = 0.07235464
# Iteration 103, loss = 0.06893132
# Iteration 104, loss = 0.06631420
# Iteration 105, loss = 0.06452163
# Iteration 106, loss = 0.06753062
# Iteration 107, loss = 0.06578331
# Iteration 108, loss = 0.06422991
# Iteration 109, loss = 0.06269070
# Iteration 110, loss = 0.06054013
# Iteration 111, loss = 0.06205743
# Iteration 112, loss = 0.05986554
# Iteration 113, loss = 0.06260445
# Iteration 114, loss = 0.06340152
# Iteration 115, loss = 0.05881637
# Iteration 116, loss = 0.06164653
# Iteration 117, loss = 0.06037898
# Iteration 118, loss = 0.06443065
# Iteration 119, loss = 0.07015074
# Iteration 120, loss = 0.07236823
# Iteration 121, loss = 0.07527006
# Iteration 122, loss = 0.06810973
# Iteration 123, loss = 0.06390389
# Iteration 124, loss = 0.06424915
# Iteration 125, loss = 0.06661457
# Iteration 126, loss = 0.05975974
# Iteration 127, loss = 0.05798401
# Iteration 128, loss = 0.05732040
# Iteration 129, loss = 0.05437881
# Iteration 130, loss = 0.05507322
# Iteration 131, loss = 0.05711380
# Iteration 132, loss = 0.05420939
# Iteration 133, loss = 0.05205071
# Iteration 134, loss = 0.05470084
# Iteration 135, loss = 0.05818695
# Iteration 136, loss = 0.05401944
# Iteration 137, loss = 0.05577803
# Iteration 138, loss = 0.05432622
# Iteration 139, loss = 0.05081191
# Iteration 140, loss = 0.05322566
# Iteration 141, loss = 0.05570151
# Iteration 142, loss = 0.05134852
# Iteration 143, loss = 0.04871172
# Iteration 144, loss = 0.05024693
# Iteration 145, loss = 0.05333077
# Iteration 146, loss = 0.05424139
# Iteration 147, loss = 0.05720380
# Iteration 148, loss = 0.05870646
# Iteration 149, loss = 0.06161635
# Iteration 150, loss = 0.06063773
# Iteration 151, loss = 0.05358273
# Iteration 152, loss = 0.05211719
# Iteration 153, loss = 0.05507000
# Iteration 154, loss = 0.05171820
# Iteration 155, loss = 0.05342961
# Iteration 156, loss = 0.05597488
# Iteration 157, loss = 0.04925846
# Iteration 158, loss = 0.04971916
# Iteration 159, loss = 0.04950700
# Iteration 160, loss = 0.04649750
# Iteration 161, loss = 0.04273016
# Iteration 162, loss = 0.04378387
# Iteration 163, loss = 0.04384555
# Iteration 164, loss = 0.04623252
# Iteration 165, loss = 0.04260758
# Iteration 166, loss = 0.04095541
# Iteration 167, loss = 0.04120579
# Iteration 168, loss = 0.04301091
# Iteration 169, loss = 0.04180009
# Iteration 170, loss = 0.04278567
# Iteration 171, loss = 0.04234555
# Iteration 172, loss = 0.04058307
# Iteration 173, loss = 0.04142264
# Iteration 174, loss = 0.04341717
# Iteration 175, loss = 0.04347978
# Iteration 176, loss = 0.03926315
# Iteration 177, loss = 0.04270001
# Iteration 178, loss = 0.04749449
# Iteration 179, loss = 0.04288760
# Iteration 180, loss = 0.04285974
# Iteration 181, loss = 0.03998539
# Iteration 182, loss = 0.04415102
# Iteration 183, loss = 0.04782057
# Iteration 184, loss = 0.05123648
# Iteration 185, loss = 0.04483829
# Iteration 186, loss = 0.04089443
# Iteration 187, loss = 0.04032570
# Iteration 188, loss = 0.03908821
# Iteration 189, loss = 0.03763705
# Iteration 190, loss = 0.03776014
# Iteration 191, loss = 0.03504428
# Iteration 192, loss = 0.03597116
# Iteration 193, loss = 0.03371712
# Iteration 194, loss = 0.03848232
# Iteration 195, loss = 0.04463422
# Iteration 196, loss = 0.04288300
# Iteration 197, loss = 0.04008837
# Iteration 198, loss = 0.03741277
# Iteration 199, loss = 0.03517825
# Iteration 200, loss = 0.03298176
# Iteration 201, loss = 0.03446617
# Iteration 202, loss = 0.03451892
# Iteration 203, loss = 0.03898830
# Iteration 204, loss = 0.03866971
# Iteration 205, loss = 0.03406079
# Iteration 206, loss = 0.03442211
# Iteration 207, loss = 0.03681126
# Iteration 208, loss = 0.04097530
# Iteration 209, loss = 0.04238165
# Iteration 210, loss = 0.03987734
# Iteration 211, loss = 0.04234790
# Iteration 212, loss = 0.04087180
# Iteration 213, loss = 0.04394983
# Iteration 214, loss = 0.04382493
# Iteration 215, loss = 0.04146357
# Iteration 216, loss = 0.03958122
# Iteration 217, loss = 0.03793004
# Iteration 218, loss = 0.03623883
# Iteration 219, loss = 0.04332589
# Iteration 220, loss = 0.04076888
# Iteration 221, loss = 0.03294446
# Iteration 222, loss = 0.03201281
# Iteration 223, loss = 0.03075812
# Iteration 224, loss = 0.03137674
# Iteration 225, loss = 0.03457581
# Iteration 226, loss = 0.03583956
# Iteration 227, loss = 0.03278600
# Iteration 228, loss = 0.03156060
# Iteration 229, loss = 0.03011965
# Iteration 230, loss = 0.03085007
# Iteration 231, loss = 0.03161980
# Iteration 232, loss = 0.03046341
# Iteration 233, loss = 0.03138248
# Iteration 234, loss = 0.03264807
# Iteration 235, loss = 0.03049572
# Iteration 236, loss = 0.02884651
# Iteration 237, loss = 0.03095313
# Iteration 238, loss = 0.03212030
# Iteration 239, loss = 0.03329758
# Iteration 240, loss = 0.03222077
# Iteration 241, loss = 0.03167528
# Iteration 242, loss = 0.03675863
# Iteration 243, loss = 0.04651849
# Iteration 244, loss = 0.04108550
# Iteration 245, loss = 0.03382614
# Iteration 246, loss = 0.03109769
# Iteration 247, loss = 0.03080789
# Iteration 248, loss = 0.02894207
# Iteration 249, loss = 0.02642067
# Iteration 250, loss = 0.02989187
# Iteration 251, loss = 0.02823037
# Iteration 252, loss = 0.03149934
# Iteration 253, loss = 0.03694128
# Iteration 254, loss = 0.04119466
# Iteration 255, loss = 0.03386204
# Iteration 256, loss = 0.03381901
# Iteration 257, loss = 0.03209986
# Iteration 258, loss = 0.02801333
# Iteration 259, loss = 0.02754539
# Iteration 260, loss = 0.02672695
# Iteration 261, loss = 0.02581888
# Iteration 262, loss = 0.02571402
# Iteration 263, loss = 0.02477264
# Iteration 264, loss = 0.02893511
# Iteration 265, loss = 0.02857401
# Iteration 266, loss = 0.02767068
# Iteration 267, loss = 0.02916969
# Iteration 268, loss = 0.02807484
# Iteration 269, loss = 0.02629095
# Iteration 270, loss = 0.02514056
# Iteration 271, loss = 0.02650313
# Iteration 272, loss = 0.02569373
# Iteration 273, loss = 0.02593546
# Iteration 274, loss = 0.02672155
# Iteration 275, loss = 0.02563135
# Iteration 276, loss = 0.02705303
# Iteration 277, loss = 0.02655425
# Iteration 278, loss = 0.02877689
# Iteration 279, loss = 0.02543129
# Iteration 280, loss = 0.02358347
# Iteration 281, loss = 0.02312666
# Iteration 282, loss = 0.02096178
# Iteration 283, loss = 0.02103572
# Iteration 284, loss = 0.02078699
# Iteration 285, loss = 0.02110540
# Iteration 286, loss = 0.02065353
# Iteration 287, loss = 0.02262408
# Iteration 288, loss = 0.02198983
# Iteration 289, loss = 0.02043128
# Iteration 290, loss = 0.01944488
# Iteration 291, loss = 0.01982751
# Iteration 292, loss = 0.02098642
# Iteration 293, loss = 0.02274764
# Iteration 294, loss = 0.02071339
# Iteration 295, loss = 0.02400996
# Iteration 296, loss = 0.02146905
# Iteration 297, loss = 0.02215916
# Iteration 298, loss = 0.02184345
# Iteration 299, loss = 0.02212689
# Iteration 300, loss = 0.02476799
# Iteration 301, loss = 0.02328974
# Iteration 302, loss = 0.02663249
# Iteration 303, loss = 0.02587985
# Iteration 304, loss = 0.02459682
# Iteration 305, loss = 0.02699338
# Iteration 306, loss = 0.02674536
# Iteration 307, loss = 0.02852512
# Iteration 308, loss = 0.02918543
# Iteration 309, loss = 0.02877415
# Iteration 310, loss = 0.02517582
# Iteration 311, loss = 0.02356943
# Iteration 312, loss = 0.02157336
# Iteration 313, loss = 0.02221221
# Iteration 314, loss = 0.02370395
# Iteration 315, loss = 0.02089354
# Iteration 316, loss = 0.02188954
# Iteration 317, loss = 0.02101415
# Iteration 318, loss = 0.02023363
# Iteration 319, loss = 0.02035539
# Iteration 320, loss = 0.02086527
# Iteration 321, loss = 0.01918264
# Iteration 322, loss = 0.01960284
# Iteration 323, loss = 0.02152162
# Iteration 324, loss = 0.02415951
# Iteration 325, loss = 0.02711614
# Iteration 326, loss = 0.02410498
# Iteration 327, loss = 0.02426161
# Iteration 328, loss = 0.01939280
# Iteration 329, loss = 0.01955893
# Iteration 330, loss = 0.02005117
# Iteration 331, loss = 0.02071200
# Iteration 332, loss = 0.01986632
# Iteration 333, loss = 0.02195931
# Iteration 334, loss = 0.02376201
# Iteration 335, loss = 0.02204498
# Iteration 336, loss = 0.02006942
# Iteration 337, loss = 0.01944570
# Iteration 338, loss = 0.01977062
# Iteration 339, loss = 0.01769426
# Iteration 340, loss = 0.01807219
# Iteration 341, loss = 0.01733490
# Iteration 342, loss = 0.01791011
# Iteration 343, loss = 0.01868702
# Iteration 344, loss = 0.01682960
# Iteration 345, loss = 0.01639498
# Iteration 346, loss = 0.01751122
# Iteration 347, loss = 0.02006278
# Iteration 348, loss = 0.01817713
# Iteration 349, loss = 0.01750748
# Iteration 350, loss = 0.01763414
# Iteration 351, loss = 0.01923189
# Iteration 352, loss = 0.02040489
# Iteration 353, loss = 0.01976595
# Iteration 354, loss = 0.02013681
# Iteration 355, loss = 0.01853464
# Iteration 356, loss = 0.01802927
# Iteration 357, loss = 0.02005519
# Iteration 358, loss = 0.02475789
# Iteration 359, loss = 0.02289236
# Iteration 360, loss = 0.01802719
# Iteration 361, loss = 0.02025129
# Iteration 362, loss = 0.01935332
# Iteration 363, loss = 0.01740030
# Iteration 364, loss = 0.01740889
# Iteration 365, loss = 0.01703922
# Iteration 366, loss = 0.01871356
# Iteration 367, loss = 0.01698877
# Iteration 368, loss = 0.01565139
# Iteration 369, loss = 0.01803256
# Iteration 370, loss = 0.01717451
# Iteration 371, loss = 0.01683725
# Iteration 372, loss = 0.01523683
# Iteration 373, loss = 0.01678328
# Iteration 374, loss = 0.01691970
# Iteration 375, loss = 0.02059508
# Iteration 376, loss = 0.01731828
# Iteration 377, loss = 0.01438791
# Iteration 378, loss = 0.01432578
# Iteration 379, loss = 0.01442842
# Iteration 380, loss = 0.01529240
# Iteration 381, loss = 0.01617517
# Iteration 382, loss = 0.01536786
# Iteration 383, loss = 0.01554074
# Iteration 384, loss = 0.01606024
# Iteration 385, loss = 0.01620858
# Iteration 386, loss = 0.01932771
# Iteration 387, loss = 0.01521926
# Iteration 388, loss = 0.01394037
# Iteration 389, loss = 0.01391316
# Iteration 390, loss = 0.01443044
# Iteration 391, loss = 0.01468995
# Iteration 392, loss = 0.01720496
# Iteration 393, loss = 0.02448948
# Iteration 394, loss = 0.02311990
# Iteration 395, loss = 0.02192111
# Iteration 396, loss = 0.02287128
# Iteration 397, loss = 0.02038554
# Iteration 398, loss = 0.01857398
# Iteration 399, loss = 0.02161915
# Iteration 400, loss = 0.02036803
# Iteration 401, loss = 0.02112950
# Iteration 402, loss = 0.02158390
# Iteration 403, loss = 0.02079158
# Iteration 404, loss = 0.02025774
# Iteration 405, loss = 0.01993951
# Iteration 406, loss = 0.01986854
# Iteration 407, loss = 0.01854285
# Iteration 408, loss = 0.01983613
# Iteration 409, loss = 0.01815279
# Iteration 410, loss = 0.01807838
# Iteration 411, loss = 0.01736555
# Iteration 412, loss = 0.01575708
# Iteration 413, loss = 0.01778389
# Iteration 414, loss = 0.01638117
# Iteration 415, loss = 0.01527742
# Iteration 416, loss = 0.01518547
# Iteration 417, loss = 0.01409483
# Iteration 418, loss = 0.01371407
# Iteration 419, loss = 0.01414424
# Iteration 420, loss = 0.01290500
# Iteration 421, loss = 0.01446383
# Iteration 422, loss = 0.01420735
# Iteration 423, loss = 0.01508665
# Iteration 424, loss = 0.01388855
# Iteration 425, loss = 0.01366221
# Iteration 426, loss = 0.01256088
# Iteration 427, loss = 0.01267224
# Iteration 428, loss = 0.01489225
# Iteration 429, loss = 0.01882594
# Iteration 430, loss = 0.02212538
# Iteration 431, loss = 0.02213410
# Iteration 432, loss = 0.02127568
# Iteration 433, loss = 0.02494331
# Iteration 434, loss = 0.02317237
# Iteration 435, loss = 0.02374578
# Iteration 436, loss = 0.02330560
# Iteration 437, loss = 0.02032140
# Iteration 438, loss = 0.01749188
# Iteration 439, loss = 0.01730888
# Iteration 440, loss = 0.01811281
# Iteration 441, loss = 0.01573190
# Iteration 442, loss = 0.01541983
# Iteration 443, loss = 0.01516437
# Iteration 444, loss = 0.01254388
# Iteration 445, loss = 0.01398788
# Iteration 446, loss = 0.01433013
# Iteration 447, loss = 0.01824779
# Iteration 448, loss = 0.02005587
# Iteration 449, loss = 0.02021497
# Iteration 450, loss = 0.01562075
# Iteration 451, loss = 0.01724830
# Iteration 452, loss = 0.01996886
# Iteration 453, loss = 0.01700095
# Iteration 454, loss = 0.01701267
# Iteration 455, loss = 0.01652871
# Iteration 456, loss = 0.02066216
# Iteration 457, loss = 0.01600846
# Iteration 458, loss = 0.01523754
# Iteration 459, loss = 0.01212851
# Iteration 460, loss = 0.01275776
# Iteration 461, loss = 0.01185881
# Iteration 462, loss = 0.01209511
# Iteration 463, loss = 0.01663857
# Iteration 464, loss = 0.01719710
# Iteration 465, loss = 0.01549861
# Iteration 466, loss = 0.01429888
# Iteration 467, loss = 0.01625098
# Iteration 468, loss = 0.01581570
# Iteration 469, loss = 0.01545706
# Iteration 470, loss = 0.01726681
# Iteration 471, loss = 0.02294844
# Iteration 472, loss = 0.02116552
# Iteration 473, loss = 0.01908424
# Iteration 474, loss = 0.01747058
# Iteration 475, loss = 0.01383707
# Iteration 476, loss = 0.01169377
# Iteration 477, loss = 0.01261701
# Iteration 478, loss = 0.01158061
# Iteration 479, loss = 0.01205322
# Iteration 480, loss = 0.01103473
# Iteration 481, loss = 0.00984995
# Iteration 482, loss = 0.00967445
# Iteration 483, loss = 0.00996159
# Iteration 484, loss = 0.01058882
# Iteration 485, loss = 0.01036271
# Iteration 486, loss = 0.01228716
# Iteration 487, loss = 0.01213530
# Iteration 488, loss = 0.01299371
# Iteration 489, loss = 0.01229602
# Iteration 490, loss = 0.01173126
# Iteration 491, loss = 0.01100659
# Iteration 492, loss = 0.01280153
# Iteration 493, loss = 0.01283888
# Iteration 494, loss = 0.01170468
# Iteration 495, loss = 0.01069207
# Iteration 496, loss = 0.01101964
# Iteration 497, loss = 0.01285204
# Iteration 498, loss = 0.01092235
# Iteration 499, loss = 0.01108524
# Iteration 500, loss = 0.01169422
# Iteration 501, loss = 0.01296461
# Iteration 502, loss = 0.01297357
# Iteration 503, loss = 0.01520466
# Iteration 504, loss = 0.01473286
# Iteration 505, loss = 0.01587329
# Iteration 506, loss = 0.01343533
# Iteration 507, loss = 0.01382613
# Iteration 508, loss = 0.01303951
# Iteration 509, loss = 0.01217600
# Iteration 510, loss = 0.01572834
# Iteration 511, loss = 0.01486010
# Iteration 512, loss = 0.01273093
# Iteration 513, loss = 0.01254593
# Iteration 514, loss = 0.01128384
# Iteration 515, loss = 0.01255821
# Iteration 516, loss = 0.01187865
# Iteration 517, loss = 0.01449331
# Iteration 518, loss = 0.01638616
# Iteration 519, loss = 0.01737859
# Iteration 520, loss = 0.02650716
# Iteration 521, loss = 0.02996300
# Iteration 522, loss = 0.02395212
# Iteration 523, loss = 0.02288784
# Iteration 524, loss = 0.01773381
# Iteration 525, loss = 0.01674842
# Iteration 526, loss = 0.01674122
# Iteration 527, loss = 0.01318410
# Iteration 528, loss = 0.01204137
# Iteration 529, loss = 0.01189639
# Iteration 530, loss = 0.01059693
# Iteration 531, loss = 0.01034643
# Iteration 532, loss = 0.01038883
# Iteration 533, loss = 0.00930398
# Iteration 534, loss = 0.00921502
# Iteration 535, loss = 0.01004147
# Iteration 536, loss = 0.00903536
# Iteration 537, loss = 0.01006785
# Iteration 538, loss = 0.00900681
# Iteration 539, loss = 0.00990884
# Iteration 540, loss = 0.01003300
# Iteration 541, loss = 0.01072432
# Iteration 542, loss = 0.00998333
# Iteration 543, loss = 0.00987395
# Iteration 544, loss = 0.00886798
# Iteration 545, loss = 0.00948463
# Iteration 546, loss = 0.00949838
# Iteration 547, loss = 0.00933355
# Iteration 548, loss = 0.00908674
# Iteration 549, loss = 0.00841976
# Iteration 550, loss = 0.00947149
# Iteration 551, loss = 0.00968862
# Iteration 552, loss = 0.00946487
# Iteration 553, loss = 0.01026424
# Iteration 554, loss = 0.00904615
# Iteration 555, loss = 0.00810623
# Iteration 556, loss = 0.00783173
# Iteration 557, loss = 0.00782171
# Iteration 558, loss = 0.00815250
# Iteration 559, loss = 0.00860951
# Iteration 560, loss = 0.00824406
# Iteration 561, loss = 0.00810171
# Iteration 562, loss = 0.00876026
# Iteration 563, loss = 0.00853916
# Iteration 564, loss = 0.00888387
# Iteration 565, loss = 0.00905982
# Iteration 566, loss = 0.01017925
# Iteration 567, loss = 0.01139802
# Iteration 568, loss = 0.01076513
# Iteration 569, loss = 0.01251439
# Iteration 570, loss = 0.01235593
# Iteration 571, loss = 0.01075189
# Iteration 572, loss = 0.01328900
# Iteration 573, loss = 0.01186512
# Iteration 574, loss = 0.01062074
# Iteration 575, loss = 0.01012228
# Iteration 576, loss = 0.00956747
# Iteration 577, loss = 0.01175411
# Iteration 578, loss = 0.01297876
# Iteration 579, loss = 0.01152611
# Iteration 580, loss = 0.01172384
# Iteration 581, loss = 0.01425892
# Iteration 582, loss = 0.01107424
# Iteration 583, loss = 0.01116607
# Iteration 584, loss = 0.01492144
# Iteration 585, loss = 0.01483829
# Iteration 586, loss = 0.01398424
# Iteration 587, loss = 0.01339362
# Iteration 588, loss = 0.01405072
# Iteration 589, loss = 0.01572251
# Iteration 590, loss = 0.01129299
# Iteration 591, loss = 0.01139013
# Iteration 592, loss = 0.00987424
# Iteration 593, loss = 0.01125017
# Iteration 594, loss = 0.01311468
# Iteration 595, loss = 0.01333265
# Iteration 596, loss = 0.01314891
# Iteration 597, loss = 0.01435629
# Iteration 598, loss = 0.01526061
# Iteration 599, loss = 0.01353806
# Iteration 600, loss = 0.01631857
# Iteration 601, loss = 0.01490745
# Iteration 602, loss = 0.01591973
# Iteration 603, loss = 0.01649035
# Iteration 604, loss = 0.01615901
# Iteration 605, loss = 0.01425386
# Iteration 606, loss = 0.01379153
# Iteration 607, loss = 0.01461662
# Iteration 608, loss = 0.01297093
# Iteration 609, loss = 0.01243517
# Iteration 610, loss = 0.01192222
# Iteration 611, loss = 0.01016370
# Iteration 612, loss = 0.00854075
# Iteration 613, loss = 0.00819942
# Iteration 614, loss = 0.00728224
# Iteration 615, loss = 0.00733958
# Iteration 616, loss = 0.00733533
# Iteration 617, loss = 0.00684835
# Iteration 618, loss = 0.00722339
# Iteration 619, loss = 0.00875849
# Iteration 620, loss = 0.00841364
# Iteration 621, loss = 0.00906204
# Iteration 622, loss = 0.01248042
# Iteration 623, loss = 0.01331573
# Iteration 624, loss = 0.01125270
# Iteration 625, loss = 0.00973388
# Iteration 626, loss = 0.00845228
# Iteration 627, loss = 0.00922195
# Iteration 628, loss = 0.00883665
# Iteration 629, loss = 0.00840644
# Iteration 630, loss = 0.00817493
# Iteration 631, loss = 0.00756380
# Iteration 632, loss = 0.00836488
# Iteration 633, loss = 0.00877956
# Iteration 634, loss = 0.01000700
# Iteration 635, loss = 0.00896175
# Iteration 636, loss = 0.01027120
# Iteration 637, loss = 0.00916166
# Iteration 638, loss = 0.00886701
# Iteration 639, loss = 0.00948582
# Iteration 640, loss = 0.00908782
# Iteration 641, loss = 0.00788966
# Iteration 642, loss = 0.00760658
# Iteration 643, loss = 0.00723128
# Iteration 644, loss = 0.00726622
# Iteration 645, loss = 0.00672145
# Iteration 646, loss = 0.00683444
# Iteration 647, loss = 0.00759398
# Iteration 648, loss = 0.00831362
# Iteration 649, loss = 0.00766526
# Iteration 650, loss = 0.00817984
# Iteration 651, loss = 0.00958308
# Iteration 652, loss = 0.00830792
# Iteration 653, loss = 0.01106517
# Iteration 654, loss = 0.01276294
# Iteration 655, loss = 0.01308703
# Iteration 656, loss = 0.01026251
# Iteration 657, loss = 0.00958262
# Iteration 658, loss = 0.01051160
# Iteration 659, loss = 0.00996860
# Iteration 660, loss = 0.00834198
# Iteration 661, loss = 0.00794717
# Iteration 662, loss = 0.00823676
# Iteration 663, loss = 0.00765210
# Iteration 664, loss = 0.00738657
# Iteration 665, loss = 0.00782060
# Iteration 666, loss = 0.00826624
# Iteration 667, loss = 0.00704271
# Iteration 668, loss = 0.00712343
# Iteration 669, loss = 0.00673814
# Iteration 670, loss = 0.00733902
# Iteration 671, loss = 0.00743599
# Iteration 672, loss = 0.00688018
# Iteration 673, loss = 0.00741628
# Iteration 674, loss = 0.00676953
# Iteration 675, loss = 0.00645451
# Iteration 676, loss = 0.00710394
# Iteration 677, loss = 0.00680832
# Iteration 678, loss = 0.00771278
# Iteration 679, loss = 0.00719735
# Iteration 680, loss = 0.00914340
# Iteration 681, loss = 0.00753941
# Iteration 682, loss = 0.00777482
# Iteration 683, loss = 0.00758457
# Iteration 684, loss = 0.00720875
# Iteration 685, loss = 0.00680658
# Iteration 686, loss = 0.00701328
# Iteration 687, loss = 0.00750866
# Iteration 688, loss = 0.00666374
# Iteration 689, loss = 0.00734020
# Iteration 690, loss = 0.00852613
# Iteration 691, loss = 0.00887120
# Iteration 692, loss = 0.00752340
# Iteration 693, loss = 0.00690088
# Iteration 694, loss = 0.00688982
# Iteration 695, loss = 0.00762784
# Iteration 696, loss = 0.00837079
# Iteration 697, loss = 0.00749495
# Iteration 698, loss = 0.00799928
# Iteration 699, loss = 0.00776821
# Iteration 700, loss = 0.00786389
# Iteration 701, loss = 0.00900894
# Iteration 702, loss = 0.00982280
# Iteration 703, loss = 0.01036422
# Iteration 704, loss = 0.00955702
# Iteration 705, loss = 0.00900278
# Iteration 706, loss = 0.00889254
# Iteration 707, loss = 0.01221996
# Iteration 708, loss = 0.01394111
# Iteration 709, loss = 0.01312938
# Iteration 710, loss = 0.01289070
# Iteration 711, loss = 0.01187060
# Iteration 712, loss = 0.01114394
# Iteration 713, loss = 0.01125078
# Iteration 714, loss = 0.01187158
# Iteration 715, loss = 0.01167351
# Iteration 716, loss = 0.01178269
# Iteration 717, loss = 0.01182836
# Iteration 718, loss = 0.01368830
# Iteration 719, loss = 0.01616915
# Iteration 720, loss = 0.01610051
# Iteration 721, loss = 0.01406980
# Iteration 722, loss = 0.01217548
# Iteration 723, loss = 0.01290653
# Iteration 724, loss = 0.01252694
# Iteration 725, loss = 0.01136621
# Iteration 726, loss = 0.01182092
# Iteration 727, loss = 0.01041772
# Iteration 728, loss = 0.01128788
# Iteration 729, loss = 0.01160908
# Iteration 730, loss = 0.01388628
# Iteration 731, loss = 0.01312998
# Iteration 732, loss = 0.01750327
# Iteration 733, loss = 0.01512695
# Iteration 734, loss = 0.01171052
# Iteration 735, loss = 0.01153272
# Iteration 736, loss = 0.01076305
# Iteration 737, loss = 0.01065096
# Iteration 738, loss = 0.01002395
# Iteration 739, loss = 0.00797666
# Iteration 740, loss = 0.00659127
# Iteration 741, loss = 0.00656039
# Iteration 742, loss = 0.00785640
# Iteration 743, loss = 0.01092357
# Iteration 744, loss = 0.00852665
# Iteration 745, loss = 0.00860709
# Iteration 746, loss = 0.00851044
# Iteration 747, loss = 0.00710089
# Iteration 748, loss = 0.00694596
# Iteration 749, loss = 0.00728193
# Iteration 750, loss = 0.00901693
# Iteration 751, loss = 0.00818958
# Iteration 752, loss = 0.00756529
# Iteration 753, loss = 0.00620625
# Iteration 754, loss = 0.00653246
# Iteration 755, loss = 0.00605441
# Iteration 756, loss = 0.00555298
# Iteration 757, loss = 0.00528960
# Iteration 758, loss = 0.00545627
# Iteration 759, loss = 0.00548906
# Iteration 760, loss = 0.00477292
# Iteration 761, loss = 0.00492474
# Iteration 762, loss = 0.00569520
# Iteration 763, loss = 0.00478883
# Iteration 764, loss = 0.00487494
# Iteration 765, loss = 0.00619011
# Iteration 766, loss = 0.00599124
# Iteration 767, loss = 0.00536025
# Iteration 768, loss = 0.00599725
# Iteration 769, loss = 0.00555343
# Iteration 770, loss = 0.00610990
# Iteration 771, loss = 0.00576271
# Iteration 772, loss = 0.00509620
# Iteration 773, loss = 0.00506583
# Iteration 774, loss = 0.00563963
# Iteration 775, loss = 0.00583442
# Iteration 776, loss = 0.00713258
# Iteration 777, loss = 0.00764630
# Iteration 778, loss = 0.00846005
# Iteration 779, loss = 0.00923837
# Iteration 780, loss = 0.00925339
# Iteration 781, loss = 0.00933655
# Iteration 782, loss = 0.01138533
# Iteration 783, loss = 0.01454066
# Iteration 784, loss = 0.01601924
# Iteration 785, loss = 0.01802472
# Iteration 786, loss = 0.02232910
# Iteration 787, loss = 0.02013765
# Iteration 788, loss = 0.01392747
# Iteration 789, loss = 0.01104269
# Iteration 790, loss = 0.01005436
# Iteration 791, loss = 0.00859400
# Iteration 792, loss = 0.00775764
# Iteration 793, loss = 0.00839868
# Iteration 794, loss = 0.00869094
# Iteration 795, loss = 0.00711377
# Iteration 796, loss = 0.00647589
# Iteration 797, loss = 0.00672583
# Iteration 798, loss = 0.00610769
# Iteration 799, loss = 0.00620404
# Iteration 800, loss = 0.00623560
# Training Score: 0.9918931825250902
# Validation Score: 0.6078675316321163
# /home/ronan/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# <!-- Answer Section Start -->
# <div style="border: 1px solid green; padding: 10px; margin-top: 10px; border-radius: 5px">
#
# **Your answer here:**
#
# We changed the hidden_layer structure, at least two layers, but not too many because my computer is slow. We also kept ReLU activation function because it is faster to compute. We chose a quite big learning rate, but small enough to not diverge.
#
# Val_score (**0.60**) << Training_score (**0.99**)
#
#
#
#
# </div>
# <!-- Answer Section End -->

# %% [markdown]
# ## Hyperparameter tuning
#
# In this section, we are now interested in maximizing the ability of the network to predict the value of unseen examples, i.e., maximizing the **validation** score.
# You should experiment with the possible parameters of the network in order to obtain a good test score, ideally with a small learning time.
#
# Parameters to vary:
#
# - number and size of the hidden layers
# - activation function
# - stopping conditions
# - maximum number of iterations
# - initial learning rate value
#
# Results to present for the tested configurations:
#
# - Train/val score
# - training time
#
# <!-- Question Start -->
# <div style="border: 1px solid blue; padding: 20px;border-radius: 5px;">
# Present in a table the various parameters tested and the associated results.
# </div>
# <!-- Question End -->
#
# You can find a cell in the notebook a code snippet that will allow you to plot tables from python structure.
# Be methodical in the way your run your experiments and collect data. For each run, you should record the parameters and results into an external data structure.
#
# (Note that, while we encourage you to explore the solution space manually, there are existing methods in scikit-learn and other learning framework to automate this step as well, e.g., [GridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html))

# %%
data = []

# %%
params = {'activation': 'relu', 'max_iter': 492, 'hidden_layer_sizes': (100,80), 'learning_rate_init': 0.000311, 'early_stopping': False}

regr_tuna = MLPRegressor(random_state=1,
                         max_iter=params['max_iter'],
                         verbose=False,
                         hidden_layer_sizes=params['hidden_layer_sizes'],
                         early_stopping=params['early_stopping'],
                         activation=params['activation'],
                         learning_rate_init=params['learning_rate_init'],
                         solver='adam')

regr_tuna.fit(X_train, y_train)
train_score = regr_tuna.score(X_train, y_train)
print("Training Score:", train_score)
val_score = regr_tuna.score(X_val,y_val)
print("Validation Score:", val_score)

params['train_score'] = train_score
params['val_score']   = val_score
data.append(params)
# print(data)
# Out:
# /home/ronan/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training Score: 0.8720474246820434
# Validation Score: 0.7687583080606146
# /home/ronan/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (492) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# Code snippet to display a nice table in jupyter notebooks  (remove from report)
import pandas as pd
import numpy as np
# data = []
# data.append({'activation': 'relu', 'max_iter': '500', 'test_score': 0.87})
# data.append({'activation': 'tanh', 'max_iter': '200', 'early_stopping': False, 'test_score': 0.91})

table = pd.DataFrame.from_dict(data)
table = table.replace(np.nan, '-')
table = table.sort_values(by='val_score', ascending=False)
table
# Out:
#    activation  max_iter     hidden_layer_sizes  learning_rate_init  \
# 72       relu       490              (100, 80)            0.000311
# 75       relu       495              (100, 80)            0.000311
# 44       relu       400  (110, 80, 50, 30, 10)            0.000080
# 76       relu       492              (100, 80)            0.000311
# 59       relu       500              (100, 80)            0.000311
# ..        ...       ...                    ...                 ...
# 2        tanh       200             (100, 100)            0.000100
# 6    logistic       500              (100, 50)            0.000100
# 37       relu       400  (110, 80, 50, 30, 10)            0.000010
# 4        tanh       500              (100, 20)            0.000010
# 36       relu       400  (110, 80, 50, 30, 10)            0.000001
#
#     train_score  val_score early_stopping
# 72     0.871895   0.769290          False
# 75     0.872379   0.769193          False
# 44     0.870992   0.768882          False
# 76     0.872047   0.768758          False
# 59     0.873699   0.768713          False
# ..          ...        ...            ...
# 2      0.666828   0.669213              -
# 6      0.639669   0.641781              -
# 37     0.646184   0.638862          False
# 4      0.569222   0.550409              -
# 36    -0.864358  -0.936162          False
#
# [77 rows x 7 columns]

# %% [markdown]
# ## Evaluation
# <!-- Question Start -->
# <div style="border: 1px solid blue; padding: 20px;border-radius: 5px;">
#
# - From your experiments, what seems to be the best model (i.e. set of parameters) for predicting the value of a house?
# - Evaluate the score of your model on the test set that was not used for training nor for model selection.
# - Train a model using your optimal parameters on the initial 15,000 data points. Evaluate the performance using the test set. What are your thoughts on the amount of data used? Do you believe the time spent is worthwhile in terms of the improvement in performance?
# </div>
# <!-- Question End -->

# %%
test_score = regr_tuna.score(X_test,y_test)
print("Test Score:", test_score)

num_samples2 = 15000
X_i, y_i = X_all[:num_samples2], y_all[:num_samples2]

X_i_train, X_i_val, y_i_train, y_i_val = train_test_split(X_i, y_i,random_state=1, test_size = 0.20)
scaler = StandardScaler()
scaler.fit(X_i_train)
X_i_train = scaler.transform(X_i_train)
X_i_test = scaler.transform(X_test)
X_i_val = scaler.transform(X_i_val)

params_final = {'activation': 'relu', 'max_iter': 490, 'hidden_layer_sizes': (100,80), 'learning_rate_init': 0.000311, 'early_stopping': False}

regr_final = MLPRegressor(random_state=1,
                         max_iter=params_final['max_iter'],
                         verbose=False,
                         hidden_layer_sizes=params_final['hidden_layer_sizes'],
                         early_stopping=params_final['early_stopping'],
                         activation=params_final['activation'],
                         learning_rate_init=params_final['learning_rate_init'],
                         solver='adam')

regr_final.fit(X_i_train, y_i_train)
train_score_final = regr_final.score(X_i_train, y_i_train)
print("Training Score:", train_score_final)
val_score_final = regr_final.score(X_i_val, y_i_val)
print("Validation Score:", val_score_final)
test_score_final = regr_final.score(X_i_test,y_test)
print("Test Score:", test_score_final)
# Out:
# Test Score: 0.7400629486481924
# /home/ronan/.local/lib/python3.10/site-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ronan/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training Score: 0.8133368473818453
# Validation Score: 0.7938748040007997
# Test Score: -484.5492438662007

# %% [markdown]
# <!-- Answer Section Start -->
# <div style="border: 1px solid green; padding: 10px; margin-top: 10px; border-radius: 5px">
#
# **Your answer here:**
#
#
# The best model seems to be {'activation': 'relu', 'max_iter': 490, 'hidden_layer_sizes': (100,80), 'learning_rate_init': 0.000311, 'early_stopping': False}
#
#
#
#
#
# </div>
# <!-- Answer Section End -->
